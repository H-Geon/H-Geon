# %%
result = 0

# %%
def add(num):
  global result
  result += num
  return result

# %%
print(add(3))
# Out:
# 6

# %%
print(add(4))
# Out:
# 10

# %%
class Calculator:
  def __init__(self):
    self.result = 0
  def add(self,num):
    self.result += num
    return self.result

# %%
cal1= Calculator()
cal2=Calculator()

# %%
print(cal1.add(3))
# Out:
# 6

# %%
print(cal1.add(4))
# Out:
# 10

# %%
print(cal2.add(3))
# Out:
# 6

# %%
print(cal2.add(4))
# Out:
# 10

# %%
def sub(self,num):
  self.result -=num
  return self.result

# %%
class FourCal:
  pass

# %%
a= FourCal()

# %%
type(a)
# Out:
# __main__.FourCal

# %%
class FourCal:
  def setdata(self, first ,second):
    self.first = first
    self.second =second

# %%
a= FourCal()
a.setdata(4,2)

# %%
a=FourCal()

# %%
a.setdata(4,2)

# %%
print(a.first)
# Out:
# 4

# %%
print(a.second)
# Out:
# 2

# %%
a=FourCal()

# %%
b=FourCal()

# %%
a.setdata(4,2)

# %%
print(a.first)
# Out:
# 4

# %%
b.setdata(3,7)

# %%
print(b.first)
# Out:
# 3

# %%
a=FourCal()

# %%
b=FourCal()

# %%
a.setdata(4,2)

# %%
b.setdata(3,7)

# %%
id(a.first)
# Out:
# 11256160

# %%
id(b.first)
# Out:
# 11256128

# %%
class FourCal:
  def setdata(self, first,second):
    self.first = first
    self.second = second
  def add(self):
    result = self.first+self.second
    return result
  def mul(self):
    result=self.first * self.second
    return result
  def sub(self):
    result = self.first - self.second
    return result
  def div(self):
    result = self.first/self.second
    return result

# %%
a= FourCal()

# %%
b=FourCal()

# %%
a.setdata(4,2)

# %%
b.setdata(3,8)

# %%
a.add()
# Out:
# 6

# %%
a.mul()
# Out:
# 8

# %%
a.sub()
# Out:
# 2

# %%
a.div()
# Out:
# 2.0

# %%
b.add()
# Out:
# 11

# %%
b.mul()
# Out:
# 24

# %%
b.sub()
# Out:
# -5

# %%
b.div()
# Out:
# 0.375

# %%
#생성자 (Constructor)

# %%
a= FourCal()

# %%
a.add()

# %%
class FourCal:
  def __init__(self,first,second):
    self.first = first
    self.second=second
  def setdata(self,first,second):
    self.first = first
    self.second=second
  def add(self):
    result=self.first+self.second
    return result
  def mul(self):
    result = self.first*self.second
    return result
  def sub(self):
    result = self.firsl-self.second
    return result
  def div(self):
    result = self.first/self.second
    return result

# %%
a= FourCal(4,2)
print(a.first)
# Out:
# 4

# %%
class MoreFourCal(FourCal):
  pass

# %%
class MoreFourCal(FourCal):
  def pow(self):
    result = self.first**self.second
    return result

# %%
a=MoreFourCal(4,2)

# %%
a.pow()
# Out:
# 16

# %%
a=FourCal(4,0)

# %%
a.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-93-656340726662> in <module>()
# ----> 1 a.div()
#
# <ipython-input-81-b8fe38351d55> in div(self)
#      16     return result
#      17   def div(self):
# ---> 18     result = self.first/self.second
#      19     return result
#
# ZeroDivisionError: division by zero

# %%
class SafeFourCal(FourCal):
  def div(self):
    if self.second ==0:
      return 0
    else:
      return self.first/self.second

# %%
a=SafeFourCal(4,0)

# %%
a.div()
# Out:
# 0

# %%
class Family:
  lastname = "김"

# %%
print(Family.lastname)
# Out:
# 김

# %%
a=Family()

# %%
b=Family()

# %%
print(a.lastname)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-e7fa54431332> in <module>()
# ----> 1 print(a.lastname)
#
# AttributeError: 'SafeFourCal' object has no attribute 'lastname'
